# %% [markdown]
# In this notebook, we will explore Gaussian Process Machine Learning model for the external Ligand set in methanol dataset.

# %% [markdown]
# # GP Model for Nickel Catalyzed Borylation in MeOH

# %% [markdown]
# ### Load libraries

# %%
# %matplotlib inline
import math
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

from sklearn.preprocessing import MinMaxScaler, StandardScaler
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
from math import sqrt
import torch
import gpytorch

# %% [markdown]
# ### Load Preprocessed Ethanol Dataset

# %%
dataset = pd.read_csv("./data/data_MeOH_Final.csv")
dataset.head()
# Out:
#    ArylHalide_CX_Lowdin  ArylHalide_C_Chem Shift  ArylHalide_C_Electrostatic  \
# 0                  1.11                  140.296                        0.33
# 1                  1.11                  140.296                        0.33
# 2                  1.11                  140.296                        0.33
# 3                  1.11                  140.296                        0.33
# 4                  1.11                  140.296                        0.33
#
#    ArylHalide_C_Exposed Area  ArylHalide_C_Mulliken  \
# 0                      8.371                  0.338
# 1                      8.371                  0.338
# 2                      8.371                  0.338
# 3                      8.371                  0.338
# 4                      8.371                  0.338
#
#    ArylHalide_XY_Chem Shift_Max  ArylHalide_XY_Chem Shift_Min  \
# 0                       105.274                       102.178
# 1                       105.274                       102.178
# 2                       105.274                       102.178
# 3                       105.274                       102.178
# 4                       105.274                       102.178
#
#    ArylHalide_XY_Electrostatic_Max  ArylHalide_XY_Electrostatic_Min  \
# 0                           -0.291                           -0.456
# 1                           -0.291                           -0.456
# 2                           -0.291                           -0.456
# 3                           -0.291                           -0.456
# 4                           -0.291                           -0.456
#
#    ArylHalide_XY_Exposed Area_Avg  ...  Kraken_vbur_vbur_max  \
# 0                         12.9615  ...             50.731606
# 1                         12.9615  ...             80.673770
# 2                         12.9615  ...            107.755370
# 3                         12.9615  ...            117.597336
# 4                         12.9615  ...            111.484024
#
#    Kraken_vbur_vbur_min  Kraken_vbur_vtot_boltz  Kraken_vmin_r_boltz  \
# 0             50.731606               351.19888             1.840787
# 1             61.935337               479.46484             1.803143
# 2             56.694310               386.44120             1.805810
# 3             54.091050               618.03375             1.817123
# 4             57.033180               402.37967             1.816461
#
#    Kraken_vmin_vmin_boltz        Ligand  \
# 0               -0.055960      A-paPhos
# 1               -0.058457        CX-FBu
# 2               -0.058387        CX-PCy
# 3               -0.054418  Cy-BippyPhos
# 4               -0.061351   Cy-JohnPhos
#
#                                         Ligand_inchi  \
# 0  InChI=1S/C20H20NP/c1-21(2)17-13-15-20(16-14-17...
# 1  InChI=1S/C29H39P.BF4/c1-2-3-22-29(27-20-12-10-...
# 2  InChI=1S/C22H30NP/c1-4-11-19(12-5-1)23-18-10-1...
# 3  InChI=1S/C36H39N4P/c1-6-16-28(17-7-1)34-36(35(...
# 4  InChI=1S/C24H31P/c1-4-12-20(13-5-1)23-18-10-11...
#
#                                        Product_inchi  \
# 0  InChI=1S/C8H8BNO2/c11-9(12)7-1-2-8-6(5-7)3-4-1...
# 1  InChI=1S/C8H8BNO2/c11-9(12)7-1-2-8-6(5-7)3-4-1...
# 2  InChI=1S/C8H8BNO2/c11-9(12)7-1-2-8-6(5-7)3-4-1...
# 3  InChI=1S/C8H8BNO2/c11-9(12)7-1-2-8-6(5-7)3-4-1...
# 4  InChI=1S/C8H8BNO2/c11-9(12)7-1-2-8-6(5-7)3-4-1...
#
#                 Solvent_inchi  Yield
# 0  InChI=1S/CH4O/c1-2/h2H,1H3  88.86
# 1  InChI=1S/CH4O/c1-2/h2H,1H3  54.07
# 2  InChI=1S/CH4O/c1-2/h2H,1H3  74.99
# 3  InChI=1S/CH4O/c1-2/h2H,1H3  82.92
# 4  InChI=1S/CH4O/c1-2/h2H,1H3  80.25
#
# [5 rows x 163 columns]

# %%
dataset.shape
# Out:
# (779, 163)

# %%
#Twenty three unique Ligands here excluding MeO-KITPHOS due to the lack of Kraken parameters
dataset.Ligand.unique().tolist()
# Out:
# ['A-paPhos',
#  'CX-FBu',
#  'CX-PCy',
#  'Cy-BippyPhos',
#  'Cy-JohnPhos',
#  'Cy-PhenCar-Phos',
#  'Cy-vBRIDP',
#  'Kwong',
#  'MePhos',
#  'PCy3 HBF4',
#  'Ph-DavePhos',
#  'Ph-SPhos',
#  'Ph-XPhos',
#  'PMe3 HBF4',
#  'PnBu3 HBF4',
#  'P(o-Anis)3',
#  'P(p-Anis)3',
#  'P(p-F-Ph)3',
#  'PPh2Cy',
#  'PPh3',
#  'PPhtBu2',
#  'PXy3',
#  'VPhos']

# %%
#load external ligand dataset in EtOH
ex_dataset = pd.read_csv("./data/external_ligand_data_MeOH.csv")
ex_dataset.head()
# Out:
#    ArylHalide_CX_Lowdin  ArylHalide_C_Chem Shift  ArylHalide_C_Electrostatic  \
# 0                  1.09                  129.449                       0.124
# 1                  1.09                  129.449                       0.124
# 2                  1.09                  129.449                       0.124
# 3                  1.09                  129.449                       0.124
# 4                  1.09                  129.449                       0.124
#
#    ArylHalide_C_Exposed Area  ArylHalide_C_Mulliken  \
# 0                      7.356                  0.004
# 1                      7.356                  0.004
# 2                      7.356                  0.004
# 3                      7.356                  0.004
# 4                      7.356                  0.004
#
#    ArylHalide_XY_Chem Shift_Max  ArylHalide_XY_Chem Shift_Min  \
# 0                       120.935                       118.065
# 1                       120.935                       118.065
# 2                       120.935                       118.065
# 3                       120.935                       118.065
# 4                       120.935                       118.065
#
#    ArylHalide_XY_Electrostatic_Max  ArylHalide_XY_Electrostatic_Min  \
# 0                           -0.177                           -0.341
# 1                           -0.177                           -0.341
# 2                           -0.177                           -0.341
# 3                           -0.177                           -0.341
# 4                           -0.177                           -0.341
#
#    ArylHalide_XY_Exposed Area_Avg  ...  Kraken_vbur_vbur_max  \
# 0                          13.589  ...            117.552360
# 1                          13.589  ...            124.748184
# 2                          13.589  ...            109.966415
# 3                          13.589  ...             49.582157
# 4                          13.589  ...             54.862930
#
#    Kraken_vbur_vbur_min  Kraken_vbur_vtot_boltz  Kraken_vmin_r_boltz  \
# 0             56.790530               430.68256             1.797235
# 1             58.538240               497.10650             1.784157
# 2             55.457000               415.06253             1.801754
# 3             43.828636               151.64550             1.826696
# 4             51.901974               330.64270             1.833448
#
#    Kraken_vmin_vmin_boltz           Ligand  \
# 0               -0.062511  Cy-JohnPhos-OMe
# 1               -0.063670            CPhos
# 2               -0.061979        CX-POMeCy
# 3               -0.062157             PEt3
# 4               -0.054343     PPh2(o-Anis)
#
#                                         Ligand_inchi  \
# 0  InChI=1S/C25H33OP/c1-26-24-18-10-8-16-22(24)23...
# 1  InChI=1S/C28H41N2P/c1-29(2)25-19-13-20-26(30(3...
# 2  InChI=1S/C23H32NOP/c1-25-22-16-9-8-15-21(22)24...
# 3        InChI=1S/C6H15P/c1-4-7(5-2)6-3/h4-6H2,1-3H3
# 4  InChI=1S/C19H17OP/c1-20-18-14-8-9-15-19(18)21(...
#
#                                        Product_inchi  \
# 0  InChI=1S/C8H7BO3/c10-9(11)7-1-2-8-6(5-7)3-4-12...
# 1  InChI=1S/C8H7BO3/c10-9(11)7-1-2-8-6(5-7)3-4-12...
# 2  InChI=1S/C8H7BO3/c10-9(11)7-1-2-8-6(5-7)3-4-12...
# 3  InChI=1S/C8H7BO3/c10-9(11)7-1-2-8-6(5-7)3-4-12...
# 4  InChI=1S/C8H7BO3/c10-9(11)7-1-2-8-6(5-7)3-4-12...
#
#                 Solvent_inchi  Yield
# 0  InChI=1S/CH4O/c1-2/h2H,1H3  72.51
# 1  InChI=1S/CH4O/c1-2/h2H,1H3  59.62
# 2  InChI=1S/CH4O/c1-2/h2H,1H3  85.04
# 3  InChI=1S/CH4O/c1-2/h2H,1H3  55.37
# 4  InChI=1S/CH4O/c1-2/h2H,1H3  74.73
#
# [5 rows x 163 columns]

# %%
#12 new external ligands
ex_dataset.Ligand.unique().tolist()
# Out:
# ['Cy-JohnPhos-OMe',
#  'CPhos',
#  'CX-POMeCy',
#  'PEt3',
#  'PPh2(o-Anis)',
#  'RuPhos',
#  'P(p-CF3-Ph)3',
#  'CM-Phos',
#  'PBn3',
#  'CX-PInCy',
#  'S-Phos',
#  'PPhCy2']

# %%
#Training set
ML_data_traintest = dataset
ML_data_traintest2 = ML_data_traintest.drop(['Electrophile_inchi', 'Solvent_inchi', 'Ligand_inchi', 'Product_inchi', 'Electrophile', 'Ligand'], axis = 1)
print (ML_data_traintest2.shape)
ML_data_traintest2.head()
# Out:
# (779, 157)
#    ArylHalide_CX_Lowdin  ArylHalide_C_Chem Shift  ArylHalide_C_Electrostatic  \
# 0                  1.11                  140.296                        0.33
# 1                  1.11                  140.296                        0.33
# 2                  1.11                  140.296                        0.33
# 3                  1.11                  140.296                        0.33
# 4                  1.11                  140.296                        0.33
#
#    ArylHalide_C_Exposed Area  ArylHalide_C_Mulliken  \
# 0                      8.371                  0.338
# 1                      8.371                  0.338
# 2                      8.371                  0.338
# 3                      8.371                  0.338
# 4                      8.371                  0.338
#
#    ArylHalide_XY_Chem Shift_Max  ArylHalide_XY_Chem Shift_Min  \
# 0                       105.274                       102.178
# 1                       105.274                       102.178
# 2                       105.274                       102.178
# 3                       105.274                       102.178
# 4                       105.274                       102.178
#
#    ArylHalide_XY_Electrostatic_Max  ArylHalide_XY_Electrostatic_Min  \
# 0                           -0.291                           -0.456
# 1                           -0.291                           -0.456
# 2                           -0.291                           -0.456
# 3                           -0.291                           -0.456
# 4                           -0.291                           -0.456
#
#    ArylHalide_XY_Exposed Area_Avg  ...  Kraken_vbur_qvtot_min_min  \
# 0                         12.9615  ...                  59.829678
# 1                         12.9615  ...                  47.895260
# 2                         12.9615  ...                  36.894516
# 3                         12.9615  ...                  45.164505
# 4                         12.9615  ...                  44.561430
#
#    Kraken_vbur_qvtot_min_vburminconf  Kraken_vbur_ratio_vbur_vtot_boltz  \
# 0                          59.829678                           0.144453
# 1                          67.167030                           0.134809
# 2                          75.417816                           0.211005
# 3                          77.044235                           0.160584
# 4                          72.197180                           0.212085
#
#    Kraken_vbur_vbur_boltz  Kraken_vbur_vbur_max  Kraken_vbur_vbur_min  \
# 0               50.731606             50.731606             50.731606
# 1               64.636100             80.673770             61.935337
# 2               81.541550            107.755370             56.694310
# 3               99.246600            117.597336             54.091050
# 4               85.339290            111.484024             57.033180
#
#    Kraken_vbur_vtot_boltz  Kraken_vmin_r_boltz  Kraken_vmin_vmin_boltz  Yield
# 0               351.19888             1.840787               -0.055960  88.86
# 1               479.46484             1.803143               -0.058457  54.07
# 2               386.44120             1.805810               -0.058387  74.99
# 3               618.03375             1.817123               -0.054418  82.92
# 4               402.37967             1.816461               -0.061351  80.25
#
# [5 rows x 157 columns]

# %% [markdown]
# ### Normalize Training set to unit scale with min-max function

# %%
# Response target are all adjusted between 0~1
y_train = ML_data_traintest2['Yield']/100

#Normalize the input predictors to unit scale
Data_X = ML_data_traintest2.drop(columns=['Yield'])

#Transform the training set
sc = MinMaxScaler()
X_train = sc.fit_transform(Data_X)

#convert to torch from numpy
train_x = torch.from_numpy(np.array(X_train)).float()
train_y = torch.from_numpy(np.array(y_train)).float().view(-1)

# %%
#Gaussian Process Model
class ExactGPModel(gpytorch.models.ExactGP):
    def __init__(self, train_x, train_y, likelihood):
        super(ExactGPModel, self).__init__(train_x, train_y, likelihood)
        if len(train_x) > 0:
            dims = len(train_x[0])
        else:
            dims = 0
        kernel = gpytorch.kernels.MaternKernel(nu=2.5, ard_num_dims=dims)
        self.mean_module = gpytorch.means.ConstantMean()
        self.covar_module = gpytorch.kernels.ScaleKernel(kernel)
    def forward(self, x):
        mean_x = self.mean_module(x)
        covar_x = self.covar_module(x)
        return gpytorch.distributions.MultivariateNormal(mean_x, covar_x)

# %%
# initialize likelihood and model
likelihood = gpytorch.likelihoods.GaussianLikelihood()
model = ExactGPModel(train_x, train_y, likelihood)

# %%
model.likelihood.noise_covar.register_constraint("raw_noise", gpytorch.constraints.GreaterThan(1e-5))

# %%
# Find optimal model hyperparameters
model.train()
likelihood.train()

# Use the adam optimizer
optimizer = torch.optim.Adam([
            {'params': model.parameters()},], 
            lr=0.05)

# "Loss" for GPs - the marginal log likelihood
mll = gpytorch.mlls.ExactMarginalLogLikelihood(likelihood, model)

training_iter = 50
for i in range(training_iter):
    # Zero gradients from previous iteration
    optimizer.zero_grad()
    # Output from model
    output = model(train_x)
    # Calc loss and backprop gradients
    loss = -mll(output, train_y)
    loss.backward()
    print('Iter %d/%d - Loss: %.3f  noise: %.3f' % (i + 1, training_iter, loss.item(), model.likelihood.noise.item()))
    optimizer.step()
# Out:
# Iter 1/50 - Loss: 1.037  noise: 0.693
# Iter 2/50 - Loss: 1.012  noise: 0.668
# Iter 3/50 - Loss: 0.987  noise: 0.644
# Iter 4/50 - Loss: 0.962  noise: 0.621
# Iter 5/50 - Loss: 0.938  noise: 0.598
# Iter 6/50 - Loss: 0.915  noise: 0.576
# Iter 7/50 - Loss: 0.892  noise: 0.554
# Iter 8/50 - Loss: 0.870  noise: 0.533
# Iter 9/50 - Loss: 0.848  noise: 0.512
# Iter 10/50 - Loss: 0.825  noise: 0.492
# Iter 11/50 - Loss: 0.803  noise: 0.473
# Iter 12/50 - Loss: 0.781  noise: 0.454
# Iter 13/50 - Loss: 0.759  noise: 0.436
# Iter 14/50 - Loss: 0.737  noise: 0.418
# Iter 15/50 - Loss: 0.714  noise: 0.401
# Iter 16/50 - Loss: 0.692  noise: 0.384
# Iter 17/50 - Loss: 0.669  noise: 0.368
# Iter 18/50 - Loss: 0.646  noise: 0.353
# Iter 19/50 - Loss: 0.623  noise: 0.338
# Iter 20/50 - Loss: 0.600  noise: 0.323
# Iter 21/50 - Loss: 0.577  noise: 0.309
# Iter 22/50 - Loss: 0.553  noise: 0.295
# Iter 23/50 - Loss: 0.530  noise: 0.282
# Iter 24/50 - Loss: 0.507  noise: 0.269
# Iter 25/50 - Loss: 0.483  noise: 0.257
# Iter 26/50 - Loss: 0.460  noise: 0.246
# Iter 27/50 - Loss: 0.437  noise: 0.234
# Iter 28/50 - Loss: 0.414  noise: 0.223
# Iter 29/50 - Loss: 0.391  noise: 0.213
# Iter 30/50 - Loss: 0.368  noise: 0.203
# Iter 31/50 - Loss: 0.346  noise: 0.194
# Iter 32/50 - Loss: 0.323  noise: 0.184
# Iter 33/50 - Loss: 0.301  noise: 0.176
# Iter 34/50 - Loss: 0.278  noise: 0.167
# Iter 35/50 - Loss: 0.257  noise: 0.159
# Iter 36/50 - Loss: 0.235  noise: 0.152
# Iter 37/50 - Loss: 0.213  noise: 0.144
# Iter 38/50 - Loss: 0.192  noise: 0.137
# Iter 39/50 - Loss: 0.171  noise: 0.131
# Iter 40/50 - Loss: 0.151  noise: 0.124
# Iter 41/50 - Loss: 0.130  noise: 0.118
# Iter 42/50 - Loss: 0.110  noise: 0.112
# Iter 43/50 - Loss: 0.091  noise: 0.107
# Iter 44/50 - Loss: 0.072  noise: 0.102
# Iter 45/50 - Loss: 0.053  noise: 0.097
# Iter 46/50 - Loss: 0.035  noise: 0.092
# Iter 47/50 - Loss: 0.017  noise: 0.088
# Iter 48/50 - Loss: -0.001  noise: 0.083
# Iter 49/50 - Loss: -0.017  noise: 0.079
# Iter 50/50 - Loss: -0.034  noise: 0.076

# %%
# Get into evaluation (predictive posterior) mode
model.eval()
likelihood.eval()

with torch.no_grad(), gpytorch.settings.fast_pred_var():
     train_pred = likelihood(model(train_x))
# Out:
# /opt/conda/lib/python3.8/site-packages/gpytorch/models/exact_gp.py:273: GPInputWarning: The input matches the stored training data. Did you forget to call model.train()?
#   warnings.warn(

# %%
#Check Top 50 Features by Lengthscale
ls = pd.Series(model.covar_module.base_kernel.lengthscale.detach().numpy()[0], 
               index=Data_X.columns.values, 
               name='l').sort_values()
ls.head(50)
# Out:
# ArylHalide_C_Chem Shift                    1.774592
# ArylHalide_XY_Mulliken_Min                 1.968622
# ArylHalide_XY_Natural_Min                  1.976390
# ArylHalide_XY_Chem Shift_Min               2.021823
# ArylHalide_X_Electrostatic                 2.054602
# ArylHalide_C_Electrostatic                 2.061830
# ArylHalide_XY_Lowdin_Avg                   2.086678
# ArylHalide_XY_Electrostatic_Min            2.088023
# ArylHalide_CX_Lowdin                       2.119320
# ArylHalide_XY_Mulliken_Bond_Avg            2.120933
# ArylHalide_XY_Mulliken_Bond_Max            2.162604
# ArylHalide_XY_Length_Max                   2.163608
# ArylHalide_XY_Chem Shift_Max               2.167277
# ArylHalide_C_Exposed Area                  2.179796
# ArylHalide_XY_Length_Min                   2.190724
# ArylHalide_XY_Mulliken_Bond_Min            2.208731
# ArylHalide_XY_Lowdin_Max                   2.209375
# ArylHalide_XY_Exposed Area_Avg             2.214408
# ArylHalide_XY_Lowdin_Min                   2.215369
# ArylHalide_XY_Electrostatic_Max            2.223264
# ArylHalide_XY_Exposed Area_Max             2.325267
# ArylHalide_XY_Exposed Area_Min             2.351327
# ArylHalide_XY_Mulliken_Max                 2.360894
# ArylHalide_C_Mulliken                      2.379746
# ArylHalide_XY_Natural_Max                  2.384290
# ArylHalide_X_Mulliken                      2.529153
# Kraken_vbur_ovbur_min_max                  2.770319
# Kraken_nmrtens_szz_P_boltz                 2.795957
# Kraken_pyr_P_vburminconf                   2.810491
# Kraken_sterimol_L_vburminconf              2.815988
# Kraken_vbur_qvbur_min_boltz                2.821492
# Kraken_nbo_P_rc_boltz                      2.822680
# Kraken_Pint_P_max_boltz                    2.834458
# Kraken_vbur_ovtot_min_max                  2.837242
# Kraken_vbur_qvbur_min_max                  2.845820
# Kraken_sterimol_burB5_delta                2.846793
# Kraken_vbur_max_delta_qvtot_vburminconf    2.847782
# Kraken_fukui_p_boltz                       2.849298
# Kraken_sterimol_burB1_min                  2.852991
# Kraken_vbur_qvbur_min_min                  2.857099
# Kraken_sterimol_L_max                      2.860765
# Kraken_vbur_ovbur_min_boltz                2.862321
# Kraken_vbur_qvtot_min_vburminconf          2.863637
# Kraken_sterimol_burB5_vburminconf          2.871829
# Kraken_sterimol_B5_delta                   2.876523
# Kraken_vbur_qvbur_min_vburminconf          2.877667
# Kraken_Pint_dP_boltz                       2.880224
# Kraken_vbur_max_delta_qvtot_delta          2.880227
# Kraken_sterimol_burL_max                   2.884167
# Kraken_sterimol_B1_vburminconf             2.886065
# Name: l, dtype: float32

# %% [markdown]
# ### External Ligand set Evaluation

# %%
ext_y=ex_dataset['Yield']/100
ext_X=ex_dataset.iloc[:, ex_dataset.columns.isin(Data_X.columns)]
X_ext_transformed = sc.transform(ext_X)
external_x = torch.from_numpy(np.array(X_ext_transformed)).float()
external_y = torch.from_numpy(np.array(ext_y)).float().view(-1)

# Make predictions by feeding model through likelihood
with torch.no_grad(), gpytorch.settings.fast_pred_var():
     pred = likelihood(model(external_x))
     # Get upper and lower confidence bounds; Returns 2 standard deviations above and below the mean
     lower, upper = pred.confidence_region()

# %%
plt.rcParams['figure.dpi'] = 120
fig, ax = plt.subplots()
ax.scatter(pred.mean.numpy()*100,external_y*100,label="Validation")
ax.plot( [0,100],[0,100], 'k--', lw=4)
ax.plot(train_pred.mean.numpy()*100, y_train*100, "or", alpha=0.5, label="Training")
ax.text(65,15,r'$R^2$: {:0.2f}'.format(r2_score(external_y*100,pred.mean.numpy()*100)))
ax.text(65,10,'Validation MAE: {:0.2f}'.format(mean_absolute_error(external_y*100,pred.mean.numpy()*100)))
ax.text(65,5,'Validation RMSE: {:0.2f}'.format(np.sqrt(mean_squared_error(external_y*100,pred.mean.numpy()*100))))
ax.set_xlabel('Predicted')
ax.set_ylabel('Measured')
ax.set_title('GP Ligand External set in MeOH prediction')
plt.legend()
plt.show()

# %%
# %load_ext watermark

# %%
# %watermark --iversions
# Out:
# pandas    : 1.2.0
# numpy     : 1.19.2
# torch     : 1.10.1+cu113
# matplotlib: 3.3.3
# gpytorch  : 1.6.0
# seaborn   : 0.11.1
