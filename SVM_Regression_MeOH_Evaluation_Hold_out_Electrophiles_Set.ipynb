# %% [markdown]
# # Machine Learning for Nickel Catalyzed Borylation in MeOH

# %%
import numpy as np
import pandas as pd
import sklearn

from sklearn.model_selection import GridSearchCV
from sklearn.preprocessing import StandardScaler

from sklearn.pipeline import Pipeline
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
import math as math
import matplotlib.pyplot as plt

from sklearn.svm import SVR

# %% [markdown]
# ### Load Preprocessed Methanol Dataset

# %%
dataset = pd.read_csv("./data/data_MeOH_Final.csv")
dataset.head()
# Out:
#    ArylHalide_CX_Lowdin  ArylHalide_C_Chem Shift  ArylHalide_C_Electrostatic  \
# 0                  1.11                  140.296                        0.33
# 1                  1.11                  140.296                        0.33
# 2                  1.11                  140.296                        0.33
# 3                  1.11                  140.296                        0.33
# 4                  1.11                  140.296                        0.33
#
#    ArylHalide_C_Exposed Area  ArylHalide_C_Mulliken  \
# 0                      8.371                  0.338
# 1                      8.371                  0.338
# 2                      8.371                  0.338
# 3                      8.371                  0.338
# 4                      8.371                  0.338
#
#    ArylHalide_XY_Chem Shift_Max  ArylHalide_XY_Chem Shift_Min  \
# 0                       105.274                       102.178
# 1                       105.274                       102.178
# 2                       105.274                       102.178
# 3                       105.274                       102.178
# 4                       105.274                       102.178
#
#    ArylHalide_XY_Electrostatic_Max  ArylHalide_XY_Electrostatic_Min  \
# 0                           -0.291                           -0.456
# 1                           -0.291                           -0.456
# 2                           -0.291                           -0.456
# 3                           -0.291                           -0.456
# 4                           -0.291                           -0.456
#
#    ArylHalide_XY_Exposed Area_Avg  ...  Kraken_vbur_vbur_max  \
# 0                         12.9615  ...             50.731606
# 1                         12.9615  ...             80.673770
# 2                         12.9615  ...            107.755370
# 3                         12.9615  ...            117.597336
# 4                         12.9615  ...            111.484024
#
#    Kraken_vbur_vbur_min  Kraken_vbur_vtot_boltz  Kraken_vmin_r_boltz  \
# 0             50.731606               351.19888             1.840787
# 1             61.935337               479.46484             1.803143
# 2             56.694310               386.44120             1.805810
# 3             54.091050               618.03375             1.817123
# 4             57.033180               402.37967             1.816461
#
#    Kraken_vmin_vmin_boltz        Ligand  \
# 0               -0.055960      A-paPhos
# 1               -0.058457        CX-FBu
# 2               -0.058387        CX-PCy
# 3               -0.054418  Cy-BippyPhos
# 4               -0.061351   Cy-JohnPhos
#
#                                         Ligand_inchi  \
# 0  InChI=1S/C20H20NP/c1-21(2)17-13-15-20(16-14-17...
# 1  InChI=1S/C29H39P.BF4/c1-2-3-22-29(27-20-12-10-...
# 2  InChI=1S/C22H30NP/c1-4-11-19(12-5-1)23-18-10-1...
# 3  InChI=1S/C36H39N4P/c1-6-16-28(17-7-1)34-36(35(...
# 4  InChI=1S/C24H31P/c1-4-12-20(13-5-1)23-18-10-11...
#
#                                        Product_inchi  \
# 0  InChI=1S/C8H8BNO2/c11-9(12)7-1-2-8-6(5-7)3-4-1...
# 1  InChI=1S/C8H8BNO2/c11-9(12)7-1-2-8-6(5-7)3-4-1...
# 2  InChI=1S/C8H8BNO2/c11-9(12)7-1-2-8-6(5-7)3-4-1...
# 3  InChI=1S/C8H8BNO2/c11-9(12)7-1-2-8-6(5-7)3-4-1...
# 4  InChI=1S/C8H8BNO2/c11-9(12)7-1-2-8-6(5-7)3-4-1...
#
#                 Solvent_inchi  Yield
# 0  InChI=1S/CH4O/c1-2/h2H,1H3  88.86
# 1  InChI=1S/CH4O/c1-2/h2H,1H3  54.07
# 2  InChI=1S/CH4O/c1-2/h2H,1H3  74.99
# 3  InChI=1S/CH4O/c1-2/h2H,1H3  82.92
# 4  InChI=1S/CH4O/c1-2/h2H,1H3  80.25
#
# [5 rows x 163 columns]

# %% [markdown]
# ### Prepare Hold-out Electrophiles Testing Set¶

# %%
dataset.Electrophile.unique().tolist()
# Out:
# ['1H-indol-5-yl\xa0N,N-dimethylsulfamate',
#  "2-bromo-1,1'-biphenyl",
#  '2-Chloro-5-fluorotoluene',
#  '2-Chloro-m-xylene',
#  '(2-Methyl-1,3-benzothiazol-5-yl)\xa0N,N-dimethylsulfamate',
#  '3-Bromothiophene',
#  '3-Chloro-2-methylaniline',
#  '4-Bromoanisole',
#  '4-Bromobenzotrifluoride',
#  '4-Chloro-N,N-dimethylbenzamide',
#  '5-chloroindole',
#  'BMS-929356',
#  'Ethyl\xa04-chloro-3-fluorobenzoate',
#  'methyl\xa04-bromobenzoate',
#  'quinolin-6-yl dimethylsulfamate',
#  '3-Bromoquinoline',
#  '3-bromo-2-methylpyridine',
#  'Clofibrate',
#  '4-Bromo-2-fluoroanisole',
#  '4-Bromo-2-fluorobenzonitrile',
#  '(4-Phenylphenyl) N,N-dimethylsulfamate',
#  '4-Bromo-1,2-(methylenedioxy)benzene',
#  '5-Bromobenzofuran',
#  '4-chloro-1-fluoro-2-methoxybenzene',
#  '4-chlorobenzotrifluoride',
#  '3-chloroquinoline',
#  '5-bromo-2,4-dimethoxypyrimidine',
#  'methyl\xa04-chlorobenzoate',
#  '5-Chloro-1,3-benzodioxole',
#  '4-chloro-2-fluoro-1-methoxybenzene',
#  '4-Chloro-2-fluoroanisole',
#  '4-Chlorobiphenyl',
#  '4-Bromobiphenyl',
#  '4-Chloro-2-fluorobenzonitrile']

# %%
indices=[0,12,17]
mapped = map(dataset.Electrophile.unique().tolist().__getitem__, indices)
external_list=list(mapped)
ML_data_validation = dataset[dataset['Electrophile'].isin(external_list)]
ML_data_validation2 = ML_data_validation.drop(['Electrophile_inchi', 'Solvent_inchi', 'Ligand_inchi', 'Product_inchi', 'Electrophile', 'Ligand'], axis = 1)
print (ML_data_validation2.shape)
ML_data_validation2.head()
# Out:
# (69, 157)
#    ArylHalide_CX_Lowdin  ArylHalide_C_Chem Shift  ArylHalide_C_Electrostatic  \
# 0                  1.11                  140.296                        0.33
# 1                  1.11                  140.296                        0.33
# 2                  1.11                  140.296                        0.33
# 3                  1.11                  140.296                        0.33
# 4                  1.11                  140.296                        0.33
#
#    ArylHalide_C_Exposed Area  ArylHalide_C_Mulliken  \
# 0                      8.371                  0.338
# 1                      8.371                  0.338
# 2                      8.371                  0.338
# 3                      8.371                  0.338
# 4                      8.371                  0.338
#
#    ArylHalide_XY_Chem Shift_Max  ArylHalide_XY_Chem Shift_Min  \
# 0                       105.274                       102.178
# 1                       105.274                       102.178
# 2                       105.274                       102.178
# 3                       105.274                       102.178
# 4                       105.274                       102.178
#
#    ArylHalide_XY_Electrostatic_Max  ArylHalide_XY_Electrostatic_Min  \
# 0                           -0.291                           -0.456
# 1                           -0.291                           -0.456
# 2                           -0.291                           -0.456
# 3                           -0.291                           -0.456
# 4                           -0.291                           -0.456
#
#    ArylHalide_XY_Exposed Area_Avg  ...  Kraken_vbur_qvtot_min_min  \
# 0                         12.9615  ...                  59.829678
# 1                         12.9615  ...                  47.895260
# 2                         12.9615  ...                  36.894516
# 3                         12.9615  ...                  45.164505
# 4                         12.9615  ...                  44.561430
#
#    Kraken_vbur_qvtot_min_vburminconf  Kraken_vbur_ratio_vbur_vtot_boltz  \
# 0                          59.829678                           0.144453
# 1                          67.167030                           0.134809
# 2                          75.417816                           0.211005
# 3                          77.044235                           0.160584
# 4                          72.197180                           0.212085
#
#    Kraken_vbur_vbur_boltz  Kraken_vbur_vbur_max  Kraken_vbur_vbur_min  \
# 0               50.731606             50.731606             50.731606
# 1               64.636100             80.673770             61.935337
# 2               81.541550            107.755370             56.694310
# 3               99.246600            117.597336             54.091050
# 4               85.339290            111.484024             57.033180
#
#    Kraken_vbur_vtot_boltz  Kraken_vmin_r_boltz  Kraken_vmin_vmin_boltz  Yield
# 0               351.19888             1.840787               -0.055960  88.86
# 1               479.46484             1.803143               -0.058457  54.07
# 2               386.44120             1.805810               -0.058387  74.99
# 3               618.03375             1.817123               -0.054418  82.92
# 4               402.37967             1.816461               -0.061351  80.25
#
# [5 rows x 157 columns]

# %%
#Keep the rest of the dataset for model training purpose
exclude_list = ML_data_validation.index.values.tolist()
ML_data_traintest = dataset[~dataset.index.isin(exclude_list)]
ML_data_traintest2 = ML_data_traintest.drop(['Electrophile_inchi', 'Solvent_inchi', 'Ligand_inchi', 'Product_inchi', 'Electrophile', 'Ligand'], axis = 1)
print (ML_data_traintest2.shape)
ML_data_traintest2.head()
# Out:
# (710, 157)
#     ArylHalide_CX_Lowdin  ArylHalide_C_Chem Shift  ArylHalide_C_Electrostatic  \
# 23                  1.09                  136.282                      -0.197
# 24                  1.09                  136.282                      -0.197
# 25                  1.09                  136.282                      -0.197
# 26                  1.09                  136.282                      -0.197
# 27                  1.09                  136.282                      -0.197
#
#     ArylHalide_C_Exposed Area  ArylHalide_C_Mulliken  \
# 23                      7.369                 -0.025
# 24                      7.369                 -0.025
# 25                      7.369                 -0.025
# 26                      7.369                 -0.025
# 27                      7.369                 -0.025
#
#     ArylHalide_XY_Chem Shift_Max  ArylHalide_XY_Chem Shift_Min  \
# 23                       139.527                       126.017
# 24                       139.527                       126.017
# 25                       139.527                       126.017
# 26                       139.527                       126.017
# 27                       139.527                       126.017
#
#     ArylHalide_XY_Electrostatic_Max  ArylHalide_XY_Electrostatic_Min  \
# 23                            0.327                            0.007
# 24                            0.327                            0.007
# 25                            0.327                            0.007
# 26                            0.327                            0.007
# 27                            0.327                            0.007
#
#     ArylHalide_XY_Exposed Area_Avg  ...  Kraken_vbur_qvtot_min_min  \
# 23                           8.957  ...                  59.829678
# 24                           8.957  ...                  47.895260
# 25                           8.957  ...                  36.894516
# 26                           8.957  ...                  45.164505
# 27                           8.957  ...                  44.561430
#
#     Kraken_vbur_qvtot_min_vburminconf  Kraken_vbur_ratio_vbur_vtot_boltz  \
# 23                          59.829678                           0.144453
# 24                          67.167030                           0.134809
# 25                          75.417816                           0.211005
# 26                          77.044235                           0.160584
# 27                          72.197180                           0.212085
#
#     Kraken_vbur_vbur_boltz  Kraken_vbur_vbur_max  Kraken_vbur_vbur_min  \
# 23               50.731606             50.731606             50.731606
# 24               64.636100             80.673770             61.935337
# 25               81.541550            107.755370             56.694310
# 26               99.246600            117.597336             54.091050
# 27               85.339290            111.484024             57.033180
#
#     Kraken_vbur_vtot_boltz  Kraken_vmin_r_boltz  Kraken_vmin_vmin_boltz  \
# 23               351.19888             1.840787               -0.055960
# 24               479.46484             1.803143               -0.058457
# 25               386.44120             1.805810               -0.058387
# 26               618.03375             1.817123               -0.054418
# 27               402.37967             1.816461               -0.061351
#
#      Yield
# 23  48.175
# 24  22.925
# 25  70.335
# 26  73.775
# 27  55.420
#
# [5 rows x 157 columns]

# %%
X_train=ML_data_traintest2.drop(columns=['Yield'])
Y_train=ML_data_traintest2['Yield']

# %% [markdown]
# ### SVM

# %%
# %%time
steps = [('scaler', StandardScaler()), ('model', SVR())]
pipeline = Pipeline(steps)
parameters = {'model__C': [0.1, 1, 10, 100], 
              'model__gamma': [1,0.1,0.01,0.001],
              'model__kernel': ['rbf', 'poly', 'sigmoid']}

svm_search = GridSearchCV(pipeline, 
                         parameters, 
                         cv = 5, 
                         scoring="neg_mean_squared_error", 
                         verbose=3)

svm_search.fit(X_train, Y_train)
# Out:
# Fitting 5 folds for each of 48 candidates, totalling 240 fits
# [CV 1/5] END model__C=0.1, model__gamma=1, model__kernel=rbf; total time=   0.1s
# [CV 2/5] END model__C=0.1, model__gamma=1, model__kernel=rbf; total time=   0.1s
# [CV 3/5] END model__C=0.1, model__gamma=1, model__kernel=rbf; total time=   0.1s
# [CV 4/5] END model__C=0.1, model__gamma=1, model__kernel=rbf; total time=   0.1s
# [CV 5/5] END model__C=0.1, model__gamma=1, model__kernel=rbf; total time=   0.1s
# [CV 1/5] END model__C=0.1, model__gamma=1, model__kernel=poly; total time=   1.9s
# [CV 2/5] END model__C=0.1, model__gamma=1, model__kernel=poly; total time=   1.0s
# [CV 3/5] END model__C=0.1, model__gamma=1, model__kernel=poly; total time=   1.3s
# [CV 4/5] END model__C=0.1, model__gamma=1, model__kernel=poly; total time=   1.1s
# [CV 5/5] END model__C=0.1, model__gamma=1, model__kernel=poly; total time=   1.5s
# [CV 1/5] END model__C=0.1, model__gamma=1, model__kernel=sigmoid; total time=   0.1s
# [CV 2/5] END model__C=0.1, model__gamma=1, model__kernel=sigmoid; total time=   0.1s
# [CV 3/5] END model__C=0.1, model__gamma=1, model__kernel=sigmoid; total time=   0.1s
# [CV 4/5] END model__C=0.1, model__gamma=1, model__kernel=sigmoid; total time=   0.1s
# [CV 5/5] END model__C=0.1, model__gamma=1, model__kernel=sigmoid; total time=   0.1s
# [CV 1/5] END model__C=0.1, model__gamma=0.1, model__kernel=rbf; total time=   0.1s
# [CV 2/5] END model__C=0.1, model__gamma=0.1, model__kernel=rbf; total time=   0.1s
# [CV 3/5] END model__C=0.1, model__gamma=0.1, model__kernel=rbf; total time=   0.1s
# [CV 4/5] END model__C=0.1, model__gamma=0.1, model__kernel=rbf; total time=   0.1s
# [CV 5/5] END model__C=0.1, model__gamma=0.1, model__kernel=rbf; total time=   0.1s
# [CV 1/5] END model__C=0.1, model__gamma=0.1, model__kernel=poly; total time=   0.1s
# [CV 2/5] END model__C=0.1, model__gamma=0.1, model__kernel=poly; total time=   0.1s
# [CV 3/5] END model__C=0.1, model__gamma=0.1, model__kernel=poly; total time=   0.1s
# [CV 4/5] END model__C=0.1, model__gamma=0.1, model__kernel=poly; total time=   0.1s
# [CV 5/5] END model__C=0.1, model__gamma=0.1, model__kernel=poly; total time=   0.1s
# [CV 1/5] END model__C=0.1, model__gamma=0.1, model__kernel=sigmoid; total time=   0.1s
# [CV 2/5] END model__C=0.1, model__gamma=0.1, model__kernel=sigmoid; total time=   0.1s
# [CV 3/5] END model__C=0.1, model__gamma=0.1, model__kernel=sigmoid; total time=   0.1s
# [CV 4/5] END model__C=0.1, model__gamma=0.1, model__kernel=sigmoid; total time=   0.1s
# [CV 5/5] END model__C=0.1, model__gamma=0.1, model__kernel=sigmoid; total time=   0.1s
# [CV 1/5] END model__C=0.1, model__gamma=0.01, model__kernel=rbf; total time=   0.1s
# [CV 2/5] END model__C=0.1, model__gamma=0.01, model__kernel=rbf; total time=   0.1s
# [CV 3/5] END model__C=0.1, model__gamma=0.01, model__kernel=rbf; total time=   0.1s
# [CV 4/5] END model__C=0.1, model__gamma=0.01, model__kernel=rbf; total time=   0.1s
# [CV 5/5] END model__C=0.1, model__gamma=0.01, model__kernel=rbf; total time=   0.1s
# [CV 1/5] END model__C=0.1, model__gamma=0.01, model__kernel=poly; total time=   0.0s
# [CV 2/5] END model__C=0.1, model__gamma=0.01, model__kernel=poly; total time=   0.0s
# [CV 3/5] END model__C=0.1, model__gamma=0.01, model__kernel=poly; total time=   0.0s
# [CV 4/5] END model__C=0.1, model__gamma=0.01, model__kernel=poly; total time=   0.0s
# [CV 5/5] END model__C=0.1, model__gamma=0.01, model__kernel=poly; total time=   0.0s
# [CV 1/5] END model__C=0.1, model__gamma=0.01, model__kernel=sigmoid; total time=   0.1s
# [CV 2/5] END model__C=0.1, model__gamma=0.01, model__kernel=sigmoid; total time=   0.1s
# [CV 3/5] END model__C=0.1, model__gamma=0.01, model__kernel=sigmoid; total time=   0.1s
# [CV 4/5] END model__C=0.1, model__gamma=0.01, model__kernel=sigmoid; total time=   0.1s
# [CV 5/5] END model__C=0.1, model__gamma=0.01, model__kernel=sigmoid; total time=   0.1s
# [CV 1/5] END model__C=0.1, model__gamma=0.001, model__kernel=rbf; total time=   0.1s
# [CV 2/5] END model__C=0.1, model__gamma=0.001, model__kernel=rbf; total time=   0.1s
# [CV 3/5] END model__C=0.1, model__gamma=0.001, model__kernel=rbf; total time=   0.1s
# [CV 4/5] END model__C=0.1, model__gamma=0.001, model__kernel=rbf; total time=   0.1s
# [CV 5/5] END model__C=0.1, model__gamma=0.001, model__kernel=rbf; total time=   0.1s
# [CV 1/5] END model__C=0.1, model__gamma=0.001, model__kernel=poly; total time=   0.0s
# [CV 2/5] END model__C=0.1, model__gamma=0.001, model__kernel=poly; total time=   0.0s
# [CV 3/5] END model__C=0.1, model__gamma=0.001, model__kernel=poly; total time=   0.0s
# [CV 4/5] END model__C=0.1, model__gamma=0.001, model__kernel=poly; total time=   0.0s
# [CV 5/5] END model__C=0.1, model__gamma=0.001, model__kernel=poly; total time=   0.0s
# [CV 1/5] END model__C=0.1, model__gamma=0.001, model__kernel=sigmoid; total time=   0.0s
# [CV 2/5] END model__C=0.1, model__gamma=0.001, model__kernel=sigmoid; total time=   0.0s
# [CV 3/5] END model__C=0.1, model__gamma=0.001, model__kernel=sigmoid; total time=   0.0s
# [CV 4/5] END model__C=0.1, model__gamma=0.001, model__kernel=sigmoid; total time=   0.0s
# [CV 5/5] END model__C=0.1, model__gamma=0.001, model__kernel=sigmoid; total time=   0.0s
# [CV 1/5] END ..model__C=1, model__gamma=1, model__kernel=rbf; total time=   0.1s
# [CV 2/5] END ..model__C=1, model__gamma=1, model__kernel=rbf; total time=   0.1s
# [CV 3/5] END ..model__C=1, model__gamma=1, model__kernel=rbf; total time=   0.1s
# [CV 4/5] END ..model__C=1, model__gamma=1, model__kernel=rbf; total time=   0.1s
# [CV 5/5] END ..model__C=1, model__gamma=1, model__kernel=rbf; total time=   0.1s
# [CV 1/5] END .model__C=1, model__gamma=1, model__kernel=poly; total time=   1.8s
# [CV 2/5] END .model__C=1, model__gamma=1, model__kernel=poly; total time=   1.0s
# [CV 3/5] END .model__C=1, model__gamma=1, model__kernel=poly; total time=   1.3s
# [CV 4/5] END .model__C=1, model__gamma=1, model__kernel=poly; total time=   1.1s
# [CV 5/5] END .model__C=1, model__gamma=1, model__kernel=poly; total time=   1.5s
# [CV 1/5] END model__C=1, model__gamma=1, model__kernel=sigmoid; total time=   0.1s
# [CV 2/5] END model__C=1, model__gamma=1, model__kernel=sigmoid; total time=   0.1s
# [CV 3/5] END model__C=1, model__gamma=1, model__kernel=sigmoid; total time=   0.1s
# [CV 4/5] END model__C=1, model__gamma=1, model__kernel=sigmoid; total time=   0.1s
# [CV 5/5] END model__C=1, model__gamma=1, model__kernel=sigmoid; total time=   0.1s
# [CV 1/5] END model__C=1, model__gamma=0.1, model__kernel=rbf; total time=   0.1s
# [CV 2/5] END model__C=1, model__gamma=0.1, model__kernel=rbf; total time=   0.1s
# [CV 3/5] END model__C=1, model__gamma=0.1, model__kernel=rbf; total time=   0.1s
# [CV 4/5] END model__C=1, model__gamma=0.1, model__kernel=rbf; total time=   0.1s
# [CV 5/5] END model__C=1, model__gamma=0.1, model__kernel=rbf; total time=   0.1s
# [CV 1/5] END model__C=1, model__gamma=0.1, model__kernel=poly; total time=   0.2s
# [CV 2/5] END model__C=1, model__gamma=0.1, model__kernel=poly; total time=   0.4s
# [CV 3/5] END model__C=1, model__gamma=0.1, model__kernel=poly; total time=   0.2s
# [CV 4/5] END model__C=1, model__gamma=0.1, model__kernel=poly; total time=   0.3s
# [CV 5/5] END model__C=1, model__gamma=0.1, model__kernel=poly; total time=   0.3s
# [CV 1/5] END model__C=1, model__gamma=0.1, model__kernel=sigmoid; total time=   0.1s
# [CV 2/5] END model__C=1, model__gamma=0.1, model__kernel=sigmoid; total time=   0.1s
# [CV 3/5] END model__C=1, model__gamma=0.1, model__kernel=sigmoid; total time=   0.1s
# [CV 4/5] END model__C=1, model__gamma=0.1, model__kernel=sigmoid; total time=   0.1s
# [CV 5/5] END model__C=1, model__gamma=0.1, model__kernel=sigmoid; total time=   0.1s
# [CV 1/5] END model__C=1, model__gamma=0.01, model__kernel=rbf; total time=   0.1s
# [CV 2/5] END model__C=1, model__gamma=0.01, model__kernel=rbf; total time=   0.1s
# [CV 3/5] END model__C=1, model__gamma=0.01, model__kernel=rbf; total time=   0.1s
# [CV 4/5] END model__C=1, model__gamma=0.01, model__kernel=rbf; total time=   0.1s
# [CV 5/5] END model__C=1, model__gamma=0.01, model__kernel=rbf; total time=   0.1s
# [CV 1/5] END model__C=1, model__gamma=0.01, model__kernel=poly; total time=   0.0s
# [CV 2/5] END model__C=1, model__gamma=0.01, model__kernel=poly; total time=   0.0s
# [CV 3/5] END model__C=1, model__gamma=0.01, model__kernel=poly; total time=   0.0s
# [CV 4/5] END model__C=1, model__gamma=0.01, model__kernel=poly; total time=   0.0s
# [CV 5/5] END model__C=1, model__gamma=0.01, model__kernel=poly; total time=   0.0s
# [CV 1/5] END model__C=1, model__gamma=0.01, model__kernel=sigmoid; total time=   0.1s
# [CV 2/5] END model__C=1, model__gamma=0.01, model__kernel=sigmoid; total time=   0.1s
# [CV 3/5] END model__C=1, model__gamma=0.01, model__kernel=sigmoid; total time=   0.1s
# [CV 4/5] END model__C=1, model__gamma=0.01, model__kernel=sigmoid; total time=   0.1s
# [CV 5/5] END model__C=1, model__gamma=0.01, model__kernel=sigmoid; total time=   0.1s
# [CV 1/5] END model__C=1, model__gamma=0.001, model__kernel=rbf; total time=   0.1s
# [CV 2/5] END model__C=1, model__gamma=0.001, model__kernel=rbf; total time=   0.1s
# [CV 3/5] END model__C=1, model__gamma=0.001, model__kernel=rbf; total time=   0.1s
# [CV 4/5] END model__C=1, model__gamma=0.001, model__kernel=rbf; total time=   0.1s
# [CV 5/5] END model__C=1, model__gamma=0.001, model__kernel=rbf; total time=   0.1s
# [CV 1/5] END model__C=1, model__gamma=0.001, model__kernel=poly; total time=   0.0s
# [CV 2/5] END model__C=1, model__gamma=0.001, model__kernel=poly; total time=   0.0s
# [CV 3/5] END model__C=1, model__gamma=0.001, model__kernel=poly; total time=   0.0s
# [CV 4/5] END model__C=1, model__gamma=0.001, model__kernel=poly; total time=   0.0s
# [CV 5/5] END model__C=1, model__gamma=0.001, model__kernel=poly; total time=   0.0s
# [CV 1/5] END model__C=1, model__gamma=0.001, model__kernel=sigmoid; total time=   0.0s
# [CV 2/5] END model__C=1, model__gamma=0.001, model__kernel=sigmoid; total time=   0.0s
# [CV 3/5] END model__C=1, model__gamma=0.001, model__kernel=sigmoid; total time=   0.0s
# [CV 4/5] END model__C=1, model__gamma=0.001, model__kernel=sigmoid; total time=   0.0s
# [CV 5/5] END model__C=1, model__gamma=0.001, model__kernel=sigmoid; total time=   0.0s
# [CV 1/5] END .model__C=10, model__gamma=1, model__kernel=rbf; total time=   0.1s
# [CV 2/5] END .model__C=10, model__gamma=1, model__kernel=rbf; total time=   0.1s
# [CV 3/5] END .model__C=10, model__gamma=1, model__kernel=rbf; total time=   0.1s
# [CV 4/5] END .model__C=10, model__gamma=1, model__kernel=rbf; total time=   0.1s
# [CV 5/5] END .model__C=10, model__gamma=1, model__kernel=rbf; total time=   0.1s
# [CV 1/5] END model__C=10, model__gamma=1, model__kernel=poly; total time=   1.8s
# [CV 2/5] END model__C=10, model__gamma=1, model__kernel=poly; total time=   1.0s
# [CV 3/5] END model__C=10, model__gamma=1, model__kernel=poly; total time=   1.3s
# [CV 4/5] END model__C=10, model__gamma=1, model__kernel=poly; total time=   1.1s
# [CV 5/5] END model__C=10, model__gamma=1, model__kernel=poly; total time=   1.5s
# [CV 1/5] END model__C=10, model__gamma=1, model__kernel=sigmoid; total time=   0.1s
# [CV 2/5] END model__C=10, model__gamma=1, model__kernel=sigmoid; total time=   0.1s
# [CV 3/5] END model__C=10, model__gamma=1, model__kernel=sigmoid; total time=   0.1s
# [CV 4/5] END model__C=10, model__gamma=1, model__kernel=sigmoid; total time=   0.1s
# [CV 5/5] END model__C=10, model__gamma=1, model__kernel=sigmoid; total time=   0.1s
# [CV 1/5] END model__C=10, model__gamma=0.1, model__kernel=rbf; total time=   0.1s
# [CV 2/5] END model__C=10, model__gamma=0.1, model__kernel=rbf; total time=   0.1s
# [CV 3/5] END model__C=10, model__gamma=0.1, model__kernel=rbf; total time=   0.1s
# [CV 4/5] END model__C=10, model__gamma=0.1, model__kernel=rbf; total time=   0.1s
# [CV 5/5] END model__C=10, model__gamma=0.1, model__kernel=rbf; total time=   0.1s
# [CV 1/5] END model__C=10, model__gamma=0.1, model__kernel=poly; total time=   0.9s
# [CV 2/5] END model__C=10, model__gamma=0.1, model__kernel=poly; total time=   0.8s
# [CV 3/5] END model__C=10, model__gamma=0.1, model__kernel=poly; total time=   0.6s
# [CV 4/5] END model__C=10, model__gamma=0.1, model__kernel=poly; total time=   0.8s
# [CV 5/5] END model__C=10, model__gamma=0.1, model__kernel=poly; total time=   0.7s
# [CV 1/5] END model__C=10, model__gamma=0.1, model__kernel=sigmoid; total time=   0.1s
# [CV 2/5] END model__C=10, model__gamma=0.1, model__kernel=sigmoid; total time=   0.1s
# [CV 3/5] END model__C=10, model__gamma=0.1, model__kernel=sigmoid; total time=   0.1s
# [CV 4/5] END model__C=10, model__gamma=0.1, model__kernel=sigmoid; total time=   0.1s
# [CV 5/5] END model__C=10, model__gamma=0.1, model__kernel=sigmoid; total time=   0.1s
# [CV 1/5] END model__C=10, model__gamma=0.01, model__kernel=rbf; total time=   0.1s
# [CV 2/5] END model__C=10, model__gamma=0.01, model__kernel=rbf; total time=   0.1s
# [CV 3/5] END model__C=10, model__gamma=0.01, model__kernel=rbf; total time=   0.1s
# [CV 4/5] END model__C=10, model__gamma=0.01, model__kernel=rbf; total time=   0.1s
# [CV 5/5] END model__C=10, model__gamma=0.01, model__kernel=rbf; total time=   0.1s
# [CV 1/5] END model__C=10, model__gamma=0.01, model__kernel=poly; total time=   0.0s
# [CV 2/5] END model__C=10, model__gamma=0.01, model__kernel=poly; total time=   0.0s
# [CV 3/5] END model__C=10, model__gamma=0.01, model__kernel=poly; total time=   0.0s
# [CV 4/5] END model__C=10, model__gamma=0.01, model__kernel=poly; total time=   0.0s
# [CV 5/5] END model__C=10, model__gamma=0.01, model__kernel=poly; total time=   0.0s
# [CV 1/5] END model__C=10, model__gamma=0.01, model__kernel=sigmoid; total time=   0.1s
# [CV 2/5] END model__C=10, model__gamma=0.01, model__kernel=sigmoid; total time=   0.1s
# [CV 3/5] END model__C=10, model__gamma=0.01, model__kernel=sigmoid; total time=   0.1s
# [CV 4/5] END model__C=10, model__gamma=0.01, model__kernel=sigmoid; total time=   0.1s
# [CV 5/5] END model__C=10, model__gamma=0.01, model__kernel=sigmoid; total time=   0.1s
# [CV 1/5] END model__C=10, model__gamma=0.001, model__kernel=rbf; total time=   0.1s
# [CV 2/5] END model__C=10, model__gamma=0.001, model__kernel=rbf; total time=   0.1s
# [CV 3/5] END model__C=10, model__gamma=0.001, model__kernel=rbf; total time=   0.1s
# [CV 4/5] END model__C=10, model__gamma=0.001, model__kernel=rbf; total time=   0.1s
# [CV 5/5] END model__C=10, model__gamma=0.001, model__kernel=rbf; total time=   0.1s
# [CV 1/5] END model__C=10, model__gamma=0.001, model__kernel=poly; total time=   0.0s
# [CV 2/5] END model__C=10, model__gamma=0.001, model__kernel=poly; total time=   0.0s
# [CV 3/5] END model__C=10, model__gamma=0.001, model__kernel=poly; total time=   0.0s
# [CV 4/5] END model__C=10, model__gamma=0.001, model__kernel=poly; total time=   0.0s
# [CV 5/5] END model__C=10, model__gamma=0.001, model__kernel=poly; total time=   0.0s
# [CV 1/5] END model__C=10, model__gamma=0.001, model__kernel=sigmoid; total time=   0.0s
# [CV 2/5] END model__C=10, model__gamma=0.001, model__kernel=sigmoid; total time=   0.1s
# [CV 3/5] END model__C=10, model__gamma=0.001, model__kernel=sigmoid; total time=   0.0s
# [CV 4/5] END model__C=10, model__gamma=0.001, model__kernel=sigmoid; total time=   0.0s
# [CV 5/5] END model__C=10, model__gamma=0.001, model__kernel=sigmoid; total time=   0.0s
# [CV 1/5] END model__C=100, model__gamma=1, model__kernel=rbf; total time=   0.1s
# [CV 2/5] END model__C=100, model__gamma=1, model__kernel=rbf; total time=   0.1s
# [CV 3/5] END model__C=100, model__gamma=1, model__kernel=rbf; total time=   0.1s
# [CV 4/5] END model__C=100, model__gamma=1, model__kernel=rbf; total time=   0.1s
# [CV 5/5] END model__C=100, model__gamma=1, model__kernel=rbf; total time=   0.1s
# [CV 1/5] END model__C=100, model__gamma=1, model__kernel=poly; total time=   1.8s
# [CV 2/5] END model__C=100, model__gamma=1, model__kernel=poly; total time=   1.0s
# [CV 3/5] END model__C=100, model__gamma=1, model__kernel=poly; total time=   1.3s
# [CV 4/5] END model__C=100, model__gamma=1, model__kernel=poly; total time=   1.1s
# [CV 5/5] END model__C=100, model__gamma=1, model__kernel=poly; total time=   1.5s
# [CV 1/5] END model__C=100, model__gamma=1, model__kernel=sigmoid; total time=   0.1s
# [CV 2/5] END model__C=100, model__gamma=1, model__kernel=sigmoid; total time=   0.1s
# [CV 3/5] END model__C=100, model__gamma=1, model__kernel=sigmoid; total time=   0.1s
# [CV 4/5] END model__C=100, model__gamma=1, model__kernel=sigmoid; total time=   0.1s
# [CV 5/5] END model__C=100, model__gamma=1, model__kernel=sigmoid; total time=   0.1s
# [CV 1/5] END model__C=100, model__gamma=0.1, model__kernel=rbf; total time=   0.1s
# [CV 2/5] END model__C=100, model__gamma=0.1, model__kernel=rbf; total time=   0.1s
# [CV 3/5] END model__C=100, model__gamma=0.1, model__kernel=rbf; total time=   0.1s
# [CV 4/5] END model__C=100, model__gamma=0.1, model__kernel=rbf; total time=   0.1s
# [CV 5/5] END model__C=100, model__gamma=0.1, model__kernel=rbf; total time=   0.1s
# [CV 1/5] END model__C=100, model__gamma=0.1, model__kernel=poly; total time=   2.1s
# [CV 2/5] END model__C=100, model__gamma=0.1, model__kernel=poly; total time=   1.1s
# [CV 3/5] END model__C=100, model__gamma=0.1, model__kernel=poly; total time=   1.8s
# [CV 4/5] END model__C=100, model__gamma=0.1, model__kernel=poly; total time=   1.3s
# [CV 5/5] END model__C=100, model__gamma=0.1, model__kernel=poly; total time=   1.5s
# [CV 1/5] END model__C=100, model__gamma=0.1, model__kernel=sigmoid; total time=   0.1s
# [CV 2/5] END model__C=100, model__gamma=0.1, model__kernel=sigmoid; total time=   0.1s
# [CV 3/5] END model__C=100, model__gamma=0.1, model__kernel=sigmoid; total time=   0.1s
# [CV 4/5] END model__C=100, model__gamma=0.1, model__kernel=sigmoid; total time=   0.1s
# [CV 5/5] END model__C=100, model__gamma=0.1, model__kernel=sigmoid; total time=   0.1s
# [CV 1/5] END model__C=100, model__gamma=0.01, model__kernel=rbf; total time=   0.1s
# [CV 2/5] END model__C=100, model__gamma=0.01, model__kernel=rbf; total time=   0.1s
# [CV 3/5] END model__C=100, model__gamma=0.01, model__kernel=rbf; total time=   0.1s
# [CV 4/5] END model__C=100, model__gamma=0.01, model__kernel=rbf; total time=   0.1s
# [CV 5/5] END model__C=100, model__gamma=0.01, model__kernel=rbf; total time=   0.1s
# [CV 1/5] END model__C=100, model__gamma=0.01, model__kernel=poly; total time=   0.1s
# [CV 2/5] END model__C=100, model__gamma=0.01, model__kernel=poly; total time=   0.1s
# [CV 3/5] END model__C=100, model__gamma=0.01, model__kernel=poly; total time=   0.1s
# [CV 4/5] END model__C=100, model__gamma=0.01, model__kernel=poly; total time=   0.1s
# [CV 5/5] END model__C=100, model__gamma=0.01, model__kernel=poly; total time=   0.1s
# [CV 1/5] END model__C=100, model__gamma=0.01, model__kernel=sigmoid; total time=   0.1s
# [CV 2/5] END model__C=100, model__gamma=0.01, model__kernel=sigmoid; total time=   0.1s
# [CV 3/5] END model__C=100, model__gamma=0.01, model__kernel=sigmoid; total time=   0.1s
# [CV 4/5] END model__C=100, model__gamma=0.01, model__kernel=sigmoid; total time=   0.1s
# [CV 5/5] END model__C=100, model__gamma=0.01, model__kernel=sigmoid; total time=   0.1s
# [CV 1/5] END model__C=100, model__gamma=0.001, model__kernel=rbf; total time=   0.1s
# [CV 2/5] END model__C=100, model__gamma=0.001, model__kernel=rbf; total time=   0.1s
# [CV 3/5] END model__C=100, model__gamma=0.001, model__kernel=rbf; total time=   0.1s
# [CV 4/5] END model__C=100, model__gamma=0.001, model__kernel=rbf; total time=   0.1s
# [CV 5/5] END model__C=100, model__gamma=0.001, model__kernel=rbf; total time=   0.1s
# [CV 1/5] END model__C=100, model__gamma=0.001, model__kernel=poly; total time=   0.0s
# [CV 2/5] END model__C=100, model__gamma=0.001, model__kernel=poly; total time=   0.0s
# [CV 3/5] END model__C=100, model__gamma=0.001, model__kernel=poly; total time=   0.0s
# [CV 4/5] END model__C=100, model__gamma=0.001, model__kernel=poly; total time=   0.0s
# [CV 5/5] END model__C=100, model__gamma=0.001, model__kernel=poly; total time=   0.0s
# [CV 1/5] END model__C=100, model__gamma=0.001, model__kernel=sigmoid; total time=   0.1s
# [CV 2/5] END model__C=100, model__gamma=0.001, model__kernel=sigmoid; total time=   0.1s
# [CV 3/5] END model__C=100, model__gamma=0.001, model__kernel=sigmoid; total time=   0.1s
# [CV 4/5] END model__C=100, model__gamma=0.001, model__kernel=sigmoid; total time=   0.1s
# [CV 5/5] END model__C=100, model__gamma=0.001, model__kernel=sigmoid; total time=   0.1s
# CPU times: user 51.3 s, sys: 281 ms, total: 51.6 s
# Wall time: 51.5 s
# GridSearchCV(cv=5,
#              estimator=Pipeline(steps=[('scaler', StandardScaler()),
#                                        ('model', SVR())]),
#              param_grid={'model__C': [0.1, 1, 10, 100],
#                          'model__gamma': [1, 0.1, 0.01, 0.001],
#                          'model__kernel': ['rbf', 'poly', 'sigmoid']},
#              scoring='neg_mean_squared_error', verbose=3)

# %%
svm_search.best_params_
# Out:
# {'model__C': 10, 'model__gamma': 0.01, 'model__kernel': 'rbf'}

# %%
svm_search.best_estimator_
# Out:
# Pipeline(steps=[('scaler', StandardScaler()), ('model', SVR(C=10, gamma=0.01))])

# %% [markdown]
# ### Hold-out Electrophiles Testing set Evaluation

# %%
ext_y=ML_data_validation2['Yield']
ext_X=ML_data_validation2.iloc[:, ML_data_validation2.columns.isin(X_train.columns)]
Y_Pred = svm_search.best_estimator_.predict(ext_X)

# %%
mse = mean_squared_error(ext_y, Y_Pred)
print(math.sqrt(mse))
# Out:
# 21.14394884561336

# %%
plt.rcParams['figure.dpi'] = 150
fig, ax = plt.subplots()
ax.scatter(Y_Pred,ext_y,label="Validation")
ax.plot( [0,100],[0,100], 'k--', lw=4)
ax.plot(svm_search.best_estimator_.predict(X_train), Y_train, "or", alpha=0.5, label="Training")
ax.text(60,15,r'$R^2$: {:0.2f}'.format(r2_score(ext_y,Y_Pred)))
ax.text(60,10,'Validation MAE: {:0.2f}'.format(mean_absolute_error(Y_Pred,ext_y)))
ax.text(60,5,'Validation RMSE: {:0.2f}'.format(np.sqrt(mean_squared_error(Y_Pred,ext_y))))
ax.set_xlabel('Predicted')
ax.set_ylabel('Measured')
ax.set_title('SVM External set in MeOH prediction')
plt.legend()
plt.show()

# %%
#For rbf importance, we will use permutation importance.  
from sklearn.inspection import permutation_importance

features=np.array(X_train.columns)
perm_importance = permutation_importance(svm_search.best_estimator_, X_train, Y_train)
sorted_idx = perm_importance.importances_mean.argsort()

df=pd.DataFrame(list(zip(X_train.columns[sorted_idx], 
                      perm_importance.importances_mean[sorted_idx])))
df2 = df.sort_values(by=[1], ascending=False).head(25)
df2.columns = ['feature', 'importance']
df2.set_index('feature',inplace=True)
df2.plot(kind='barh')
# Out:
# <AxesSubplot:ylabel='feature'>

# %%
# %load_ext watermark

# %%
# %watermark --iversions
# Out:
# matplotlib: 3.3.3
# numpy     : 1.19.2
# pandas    : 1.2.0
# sklearn   : 0.24.0
